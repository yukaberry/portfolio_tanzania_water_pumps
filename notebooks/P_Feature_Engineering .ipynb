# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/Training_set_values.csv")
label = pd.read_csv("data/training_set_labels.csv")

# %%
df = pd.merge(df,label, on = "id")
df.head(22)
# Out:
#        id  amount_tsh date_recorded                   funder  gps_height  \
# 0   69572      6000.0    2011-03-14                    Roman        1390
# 1    8776         0.0    2013-03-06                  Grumeti        1399
# 2   34310        25.0    2013-02-25             Lottery Club         686
# 3   67743         0.0    2013-01-28                   Unicef         263
# 4   19728         0.0    2011-07-13              Action In A           0
# 5    9944        20.0    2011-03-13      Mkinga Distric Coun           0
# 6   19816         0.0    2012-10-01                     Dwsp           0
# 7   54551         0.0    2012-10-09                    Rwssp           0
# 8   53934         0.0    2012-11-03                 Wateraid           0
# 9   46144         0.0    2011-08-03              Isingiro Ho           0
# 10  49056         0.0    2011-02-20                  Private          62
# 11  50409       200.0    2013-02-18                   Danida        1062
# 12  36957         0.0    2012-10-14             World Vision           0
# 13  50495         0.0    2013-03-15  Lawatefuka Water Supply        1368
# 14  53752         0.0    2012-10-20                    Biore           0
# 15  61848         0.0    2011-08-04                    Rudep        1645
# 16  48451       500.0    2011-07-04                   Unicef        1703
# 17  58155         0.0    2011-09-04                   Unicef        1656
# 18  34169         0.0    2011-07-22                   Hesawa        1162
# 19  18274       500.0    2011-02-22                   Danida        1763
# 20  48375       200.0    2011-02-27                      Twe        2216
# 21   6091         0.0    2013-02-10                     Dwsp           0
#
#                installer  longitude      latitude                wpt_name  \
# 0                  Roman  34.938093 -9.856322e+00                    none
# 1                GRUMETI  34.698766 -2.147466e+00                Zahanati
# 2           World vision  37.460664 -3.821329e+00             Kwa Mahundi
# 3                 UNICEF  38.486161 -1.115530e+01    Zahanati Ya Nanyumbu
# 4                Artisan  31.130847 -1.825359e+00                 Shuleni
# 5                    DWE  39.172796 -4.765587e+00                  Tajiri
# 6                   DWSP  33.362410 -3.766365e+00              Kwa Ngomho
# 7                    DWE  32.620617 -4.226198e+00            Tushirikiane
# 8              Water Aid  32.711100 -5.146712e+00       Kwa Ramadhan Musa
# 9                Artisan  30.626991 -1.257051e+00                 Kwapeto
# 10               Private  39.209518 -7.034139e+00           Mzee Hokororo
# 11                DANIDA  35.770258 -1.057417e+01        Kwa Alid Nchimbi
# 12          World vision  33.798106 -3.290194e+00                   Pamba
# 13  Lawatefuka water sup  37.092574 -3.181783e+00    Kwa John Izack Mmari
# 14                WEDECO  34.364073 -3.629333e+00               Mwabasabi
# 15                   DWE  31.444121 -8.274962e+00  Kwa Juvenal Ching'Ombe
# 16                   DWE  34.642439 -9.106185e+00         Kwa John Mtenzi
# 17                   DWE  34.569266 -9.085515e+00         Kwa Rose Chaula
# 18                   DWE  32.920154 -1.947868e+00                  Ngomee
# 19                 Danid  34.508967 -9.894412e+00                    none
# 20                   TWE  34.473430 -9.594990e+00                    none
# 21                   DWE   0.000000 -2.000000e-08                Muungano
#
#     num_private  ... water_quality quality_group      quantity  \
# 0             0  ...          soft          good        enough
# 1             0  ...          soft          good  insufficient
# 2             0  ...          soft          good        enough
# 3             0  ...          soft          good           dry
# 4             0  ...          soft          good      seasonal
# 5             0  ...         salty         salty        enough
# 6             0  ...          soft          good        enough
# 7             0  ...         milky         milky        enough
# 8             0  ...         salty         salty      seasonal
# 9             0  ...          soft          good        enough
# 10            0  ...         salty         salty        enough
# 11            0  ...          soft          good  insufficient
# 12            0  ...          soft          good        enough
# 13            0  ...          soft          good        enough
# 14            0  ...          soft          good        enough
# 15            0  ...          soft          good        enough
# 16            0  ...          soft          good           dry
# 17            0  ...          soft          good           dry
# 18            0  ...         milky         milky  insufficient
# 19            0  ...          soft          good        enough
# 20            0  ...          soft          good        enough
# 21            0  ...       unknown       unknown       unknown
#
#     quantity_group                source           source_type source_class  \
# 0           enough                spring                spring  groundwater
# 1     insufficient  rainwater harvesting  rainwater harvesting      surface
# 2           enough                   dam                   dam      surface
# 3              dry           machine dbh              borehole  groundwater
# 4         seasonal  rainwater harvesting  rainwater harvesting      surface
# 5           enough                 other                 other      unknown
# 6           enough           machine dbh              borehole  groundwater
# 7           enough          shallow well          shallow well  groundwater
# 8         seasonal           machine dbh              borehole  groundwater
# 9           enough          shallow well          shallow well  groundwater
# 10          enough           machine dbh              borehole  groundwater
# 11    insufficient          shallow well          shallow well  groundwater
# 12          enough          shallow well          shallow well  groundwater
# 13          enough                spring                spring  groundwater
# 14          enough          shallow well          shallow well  groundwater
# 15          enough           machine dbh              borehole  groundwater
# 16             dry                 river            river/lake      surface
# 17             dry                 river            river/lake      surface
# 18    insufficient                spring                spring  groundwater
# 19          enough                spring                spring  groundwater
# 20          enough                spring                spring  groundwater
# 21         unknown          shallow well          shallow well  groundwater
#
#                 waterpoint_type waterpoint_type_group             status_group
# 0            communal standpipe    communal standpipe               functional
# 1            communal standpipe    communal standpipe               functional
# 2   communal standpipe multiple    communal standpipe               functional
# 3   communal standpipe multiple    communal standpipe           non functional
# 4            communal standpipe    communal standpipe               functional
# 5   communal standpipe multiple    communal standpipe               functional
# 6                     hand pump             hand pump           non functional
# 7                     hand pump             hand pump           non functional
# 8                     hand pump             hand pump           non functional
# 9                     hand pump             hand pump               functional
# 10                        other                 other               functional
# 11                    hand pump             hand pump               functional
# 12                    hand pump             hand pump               functional
# 13           communal standpipe    communal standpipe               functional
# 14                    hand pump             hand pump               functional
# 15                    hand pump             hand pump               functional
# 16           communal standpipe    communal standpipe           non functional
# 17           communal standpipe    communal standpipe           non functional
# 18                        other                 other  functional needs repair
# 19           communal standpipe    communal standpipe               functional
# 20           communal standpipe    communal standpipe               functional
# 21                    hand pump             hand pump               functional
#
# [22 rows x 41 columns]

# %% [markdown]
# # Keep top 10 of funder and installer

# %%
def installer_cl(df):
    if df['installer']=="DWE":
        return 'dwe'
    elif df['installer']=="Government":
        return 'gov'
    elif df['installer']=="RWE":
        return "rwe"
    elif df['installer']=="Commu":
        return"commu"
    elif df['installer']=="DANIDA":
        return"danida"
    elif df['installer']=="KKKT":
        return "kkkt"
    elif df['installer']=="Hesawa":
        return "hesewa"
    elif df['installer']=="0":
        return "unknown"
    elif df['installer']=="TCRS":
        return"tcrs"
    elif df['installer']=="Central government":
        return "central gov" 
    elif df['installer']=="NaN":
        return "nan"
    else:
        return "others"
df['installer_group'] = df.apply(lambda df: installer_cl(df), axis=1)

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ... quality_group      quantity quantity_group                source  \
# 0      ...          good        enough         enough                spring
# 1      ...          good  insufficient   insufficient  rainwater harvesting
# 2      ...          good        enough         enough                   dam
# 3      ...          good           dry            dry           machine dbh
# 4      ...          good      seasonal       seasonal  rainwater harvesting
# ...    ...           ...           ...            ...                   ...
# 59395  ...          good        enough         enough                spring
# 59396  ...          good        enough         enough                 river
# 59397  ...      fluoride        enough         enough           machine dbh
# 59398  ...          good  insufficient   insufficient          shallow well
# 59399  ...         salty        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# 0                    spring  groundwater           communal standpipe
# 1      rainwater harvesting      surface           communal standpipe
# 2                       dam      surface  communal standpipe multiple
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 59395                spring  groundwater           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#        waterpoint_type_group    status_group installer_group
# 0         communal standpipe      functional          others
# 1         communal standpipe      functional          others
# 2         communal standpipe      functional          others
# 3         communal standpipe  non functional          others
# 4         communal standpipe      functional          others
# ...                      ...             ...             ...
# 59395     communal standpipe      functional          others
# 59396     communal standpipe      functional          others
# 59397              hand pump      functional          others
# 59398              hand pump      functional          others
# 59399              hand pump      functional          others
#
# [59400 rows x 42 columns]

# %%
def funder_cl(df):
    if df['funder']=="Government Of Tanzania":
        return 'gov of Tanzania'
    elif df['funder']=="Danida":
        return 'danida'
    elif df["funder"]=="Hesawa":
        return "hesawa"
    elif df['funder']=="Rwssp":
        return"rwssp"
    elif df['funder']=="World Vision":
        return"world vision"
    elif df['funder']=="Unicef":
        return "unicef"
    elif df['funder']=="Hesawa":
        return "hesewa"
    elif df['funder']=="Tasaf":
        return "tasaf"
    elif df['funder']=="District Council":
        return"district council"
    elif df['funder']=="Kkkt":
        return "kkkt" 
    elif df['funder']=="NaN":
        return "nan"
    else:
        return "others"
df['funder_group'] = df.apply(lambda df: installer_cl(df), axis=1)

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ...      quantity quantity_group                source  \
# 0      ...        enough         enough                spring
# 1      ...  insufficient   insufficient  rainwater harvesting
# 2      ...        enough         enough                   dam
# 3      ...           dry            dry           machine dbh
# 4      ...      seasonal       seasonal  rainwater harvesting
# ...    ...           ...            ...                   ...
# 59395  ...        enough         enough                spring
# 59396  ...        enough         enough                 river
# 59397  ...        enough         enough           machine dbh
# 59398  ...  insufficient   insufficient          shallow well
# 59399  ...        enough         enough          shallow well
#
#                 source_type  source_class              waterpoint_type  \
# 0                    spring   groundwater           communal standpipe
# 1      rainwater harvesting       surface           communal standpipe
# 2                       dam       surface  communal standpipe multiple
# 3                  borehole   groundwater  communal standpipe multiple
# 4      rainwater harvesting       surface           communal standpipe
# ...                     ...           ...                          ...
# 59395                spring   groundwater           communal standpipe
# 59396            river/lake       surface           communal standpipe
# 59397              borehole   groundwater                    hand pump
# 59398          shallow well   groundwater                    hand pump
# 59399          shallow well   groundwater                    hand pump
#
#       waterpoint_type_group    status_group installer_group funder_group
# 0        communal standpipe      functional          others       others
# 1        communal standpipe      functional          others       others
# 2        communal standpipe      functional          others       others
# 3        communal standpipe  non functional          others       others
# 4        communal standpipe      functional          others       others
# ...                     ...             ...             ...          ...
# 59395    communal standpipe      functional          others       others
# 59396    communal standpipe      functional          others       others
# 59397             hand pump      functional          others       others
# 59398             hand pump      functional          others       others
# 59399             hand pump      functional          others       others
#
# [59400 rows x 43 columns]

# %% [markdown]
# # Sorting decades

# %%
def year_cl(df):
    if df["construction_year"]==0:
        return 'unknown'
    elif 1960 <= df["construction_year"]<=1969:
        return "60s"
    elif 1970 <= df["construction_year"]<=1979:
        return "70s"
    elif 1980 <= df["construction_year"]<=1989:
        return "80s"
    elif 1990 <= df["construction_year"]<=1999:
        return "90s"
    elif 2000 <= df["construction_year"]<=2009:
        return "00s"
    elif 2010 <= df["construction_year"]<=2019:
        return "10s"

df['construction_year_new'] = df.apply(lambda df: year_cl(df), axis=1)

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ... quantity_group                source           source_type  \
# 0      ...         enough                spring                spring
# 1      ...   insufficient  rainwater harvesting  rainwater harvesting
# 2      ...         enough                   dam                   dam
# 3      ...            dry           machine dbh              borehole
# 4      ...       seasonal  rainwater harvesting  rainwater harvesting
# ...    ...            ...                   ...                   ...
# 59395  ...         enough                spring                spring
# 59396  ...         enough                 river            river/lake
# 59397  ...         enough           machine dbh              borehole
# 59398  ...   insufficient          shallow well          shallow well
# 59399  ...         enough          shallow well          shallow well
#
#        source_class              waterpoint_type waterpoint_type_group  \
# 0       groundwater           communal standpipe    communal standpipe
# 1           surface           communal standpipe    communal standpipe
# 2           surface  communal standpipe multiple    communal standpipe
# 3       groundwater  communal standpipe multiple    communal standpipe
# 4           surface           communal standpipe    communal standpipe
# ...             ...                          ...                   ...
# 59395   groundwater           communal standpipe    communal standpipe
# 59396       surface           communal standpipe    communal standpipe
# 59397   groundwater                    hand pump             hand pump
# 59398   groundwater                    hand pump             hand pump
# 59399   groundwater                    hand pump             hand pump
#
#          status_group  installer_group funder_group construction_year_new
# 0          functional           others       others                   90s
# 1          functional           others       others                   10s
# 2          functional           others       others                   00s
# 3      non functional           others       others                   80s
# 4          functional           others       others               unknown
# ...               ...              ...          ...                   ...
# 59395      functional           others       others                   90s
# 59396      functional           others       others                   90s
# 59397      functional           others       others               unknown
# 59398      functional           others       others               unknown
# 59399      functional           others       others                   00s
#
# [59400 rows x 44 columns]

# %% [markdown]
# # Population zero or no zero

# %%
def pop_cl(df):
    if df["population"]==0:
        return "zero"
    else:
        return "non-zero"
df["population_zero"] = df.apply(lambda df:pop_cl(df),axis =1)

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ...                source           source_type source_class  \
# 0      ...                spring                spring  groundwater
# 1      ...  rainwater harvesting  rainwater harvesting      surface
# 2      ...                   dam                   dam      surface
# 3      ...           machine dbh              borehole  groundwater
# 4      ...  rainwater harvesting  rainwater harvesting      surface
# ...    ...                   ...                   ...          ...
# 59395  ...                spring                spring  groundwater
# 59396  ...                 river            river/lake      surface
# 59397  ...           machine dbh              borehole  groundwater
# 59398  ...          shallow well          shallow well  groundwater
# 59399  ...          shallow well          shallow well  groundwater
#
#                    waterpoint_type  waterpoint_type_group    status_group  \
# 0               communal standpipe     communal standpipe      functional
# 1               communal standpipe     communal standpipe      functional
# 2      communal standpipe multiple     communal standpipe      functional
# 3      communal standpipe multiple     communal standpipe  non functional
# 4               communal standpipe     communal standpipe      functional
# ...                            ...                    ...             ...
# 59395           communal standpipe     communal standpipe      functional
# 59396           communal standpipe     communal standpipe      functional
# 59397                    hand pump              hand pump      functional
# 59398                    hand pump              hand pump      functional
# 59399                    hand pump              hand pump      functional
#
#       installer_group  funder_group construction_year_new population_zero
# 0              others        others                   90s        non-zero
# 1              others        others                   10s        non-zero
# 2              others        others                   00s        non-zero
# 3              others        others                   80s        non-zero
# 4              others        others               unknown            zero
# ...               ...           ...                   ...             ...
# 59395          others        others                   90s        non-zero
# 59396          others        others                   90s        non-zero
# 59397          others        others               unknown            zero
# 59398          others        others               unknown            zero
# 59399          others        others                   00s        non-zero
#
# [59400 rows x 45 columns]

# %% [markdown]
# # Payment status: Paid or not paid

# %%
def pay_cl(df):
    if df["payment"]=="never pay":
        return "NeverPay"
    elif df["payment"]=="unknown":
        return "Unknown"
    else:
        return "Pay"
df["payment_status"] = df.apply(lambda df:pay_cl(df),axis =1)

# %%
df
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             Roman  34.938093  -9.856322                  none            0
# 1           GRUMETI  34.698766  -2.147466              Zahanati            0
# 2      World vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            UNICEF  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           Artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           CES  37.169807  -3.253847   Area Three Namba 27            0
# 59396          Cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397           NaN  34.017087  -8.750434               Mashine            0
# 59398          Musa  35.861315  -6.378573                Mshoro            0
# 59399         World  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ...           source_type source_class              waterpoint_type  \
# 0      ...                spring  groundwater           communal standpipe
# 1      ...  rainwater harvesting      surface           communal standpipe
# 2      ...                   dam      surface  communal standpipe multiple
# 3      ...              borehole  groundwater  communal standpipe multiple
# 4      ...  rainwater harvesting      surface           communal standpipe
# ...    ...                   ...          ...                          ...
# 59395  ...                spring  groundwater           communal standpipe
# 59396  ...            river/lake      surface           communal standpipe
# 59397  ...              borehole  groundwater                    hand pump
# 59398  ...          shallow well  groundwater                    hand pump
# 59399  ...          shallow well  groundwater                    hand pump
#
#        waterpoint_type_group    status_group installer_group funder_group  \
# 0         communal standpipe      functional          others       others
# 1         communal standpipe      functional          others       others
# 2         communal standpipe      functional          others       others
# 3         communal standpipe  non functional          others       others
# 4         communal standpipe      functional          others       others
# ...                      ...             ...             ...          ...
# 59395     communal standpipe      functional          others       others
# 59396     communal standpipe      functional          others       others
# 59397              hand pump      functional          others       others
# 59398              hand pump      functional          others       others
# 59399              hand pump      functional          others       others
#
#        construction_year_new population_zero payment_status
# 0                        90s        non-zero            Pay
# 1                        10s        non-zero       NeverPay
# 2                        00s        non-zero            Pay
# 3                        80s        non-zero       NeverPay
# 4                    unknown            zero       NeverPay
# ...                      ...             ...            ...
# 59395                    90s        non-zero            Pay
# 59396                    90s        non-zero            Pay
# 59397                unknown            zero            Pay
# 59398                unknown            zero       NeverPay
# 59399                    00s        non-zero            Pay
#
# [59400 rows x 46 columns]

# %% [markdown]
# # Longitude : missing value filled with median

# %%
df.isnull().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# status_group                 0
# dtype: int64

# %%
def replace_nan_with_zero(variable):
    df_variables=[variable]
    for i in df_variables:
        df[i].replace(0,np.nan,inplace=True)
        return df[i].isnull().sum()

# %%
replace_nan_with_zero("longitude")
# Out:
# 1812

# %%
df.isnull().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                 1812
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# status_group                 0
# dtype: int64

# %%
def return_median(variable):   
    temp_df = df[df[variable].notnull()]
    temp_df = temp_df[[variable, 'status_group']].groupby(['status_group'])[[variable]].median().reset_index()
    temp_col = temp_df[variable]
    print((type(save_it_to_a_var)))
    return temp_col

# %%
return_median("longitude")
# Out:
# <class 'pandas.core.series.Series'>
# 0    35.086368
# 1    34.183209
# 2    35.048526
# Name: longitude, dtype: float64

# %%
print(df.longitude.isnull().sum())
# Out:
# 1812

# %%
save_it_to_variable = return_median("longitude")
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(save_it_to_variable[0])
# Out:
# 35.08636786

# %%
df.loc[(df['status_group'] == "functional" ) & (df["longitude"].isnull()), "longitude"] = save_it_to_variable[0]
df.loc[(df['status_group'] == "functional needs repair" ) & (df["longitude"].isnull()), "longitude"] = save_it_to_variable[1]
df.loc[(df['status_group'] == "non functional" ) & (df["longitude"].isnull()), "longitude"] = save_it_to_variable[2]

# %%
print(df.longitude.isnull().sum())
# Out:
# 0

# %%
df.loc[21]
# Out:
# id                                          6091
# amount_tsh                                     0
# date_recorded                         2013-02-10
# funder                                      Dwsp
# gps_height                                     0
# installer                                    DWE
# longitude                                35.0864
# latitude                                  -2e-08
# wpt_name                                Muungano
# num_private                                    0
# basin                              Lake Victoria
# subvillage                            Ibabachegu
# region                                 Shinyanga
# region_code                                   17
# district_code                                  1
# lga                                      Bariadi
# ward                           Ikungulyabashashi
# population                                     0
# public_meeting                               NaN
# recorded_by              GeoData Consultants Ltd
# scheme_management                            WUG
# scheme_name                                  NaN
# permit                                     False
# construction_year                              0
# extraction_type                           swn 80
# extraction_type_group                     swn 80
# extraction_type_class                   handpump
# management                                   wug
# management_group                      user-group
# payment                                  unknown
# payment_type                             unknown
# water_quality                            unknown
# quality_group                            unknown
# quantity                                 unknown
# quantity_group                           unknown
# source                              shallow well
# source_type                         shallow well
# source_class                         groundwater
# waterpoint_type                        hand pump
# waterpoint_type_group                  hand pump
# status_group                          functional
# Name: 21, dtype: object
